# %%
from core import question, call, get_weather

question('查理芒格现在生活状况', model='deepseek')
# Out:
# 查理·芒格（Charlie Munger）作为伯克希尔·哈撒韦公司的副主席和沃伦·巴菲特的长期合作伙伴，一直是投资界的传奇人物。以下是关于他当前生活状况的详细信息（截至2023年10月）：
#
# ### 1. **年龄与健康状况**
#    - 芒格出生于1924年1月1日，现年**99岁**（2023年），即将迈入百岁高龄。
#    - 尽管年事已高，他仍保持相对活跃的公众形象。近年他偶尔会提到身体机能自然衰退（如听力下降），但整体健康状况稳定，思维依然敏锐。
#    - 他在2021年接受采访时曾调侃自己的长寿：“我本应在几年前就死了，但医生们搞错了。”
#
# ### 2. **工作与投资活动**
#    - **伯克希尔角色**：他继续担任伯克希尔的副主席，参与重大决策，但日常事务更多由巴菲特及其他高管负责。
#    - **公开露面**：每年仍出席伯克希尔股东大会，与巴菲特共同回答提问。2023年5月的股东会上，他犀利点评了加密货币、AI热潮等话题。
#    - **投资观点**：近年持续强调价值投资原则，批评投机行为（如比特币“毫无价值”），并提醒投资者关注通胀风险。
#
# ### 3. **个人生活与家庭**
#    - **居住地**：长期定居美国加利福尼亚州，拥有多处房产，包括洛杉矶的住所。
#    - **家庭**：芒格经历过两段婚姻，育有8名子女（其中2名为继子女）。他与第二任妻子南希（Nancy）相伴至她2010年去世，家庭关系紧密。
#    - **慈善**：通过家族基金会支持教育、医疗等领域，曾向密歇根大学、斯坦福大学等捐赠数亿美元。
#
# ### 4. **兴趣爱好与著作**
#    - **阅读**：保持每日数小时的阅读习惯，涉猎广泛，从心理学到科学史。
#    - **建筑设计**：热衷参与建筑项目，如设计私人游艇或资助大学校园建设。
#    - **著作**：《穷查理宝典》仍是其思想集大成之作，近年未出新书，但通过采访和演讲持续输出观点。
#
# ### 5. **近期动态**
#    - **2023年观点**：在Daily Journal年会等场合警告美国银行业风险，对中国经济（尤其是比亚迪等投资）保持乐观。
# ...
